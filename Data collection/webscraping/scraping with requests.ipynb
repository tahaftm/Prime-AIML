# %%
import requests

# %%
res = requests.get("https://books.toscrape.com/")

# %%
res.status_code
# Out:
# 200

# %%
if res.status_code == 200:
    with open("scraped_data/bookstore.html", "w") as f:
        f.write(res.text)
        print("Done writing the file")
# Out:
# Done writing the file
