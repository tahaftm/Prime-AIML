# %%
import numpy as np
import matplotlib.pyplot as plt

values = np.random.uniform(0,10,10_00_000)

plt.hist(values,bins = 100, density = True, alpha = 0.3)
plt.title("Continuose uniform distribution between 0 and 10")
plt.xlabel("X")
plt.ylabel("Probablity density")
plt.grid(True)
plt.show()

# %% [markdown]
# Find the area under the curve to find the probablity of a nhumkber lying on a certain range
